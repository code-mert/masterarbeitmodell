# %%
import sys
import os

# Pfad zum aktuellen Ordner hinzufügen
sys.path.insert(0, os.path.abspath('.'))

from headline_table_lr import create_headline_table_LR

# Headline-Tabelle berechnen und formatiert anzeigen
df_headline = create_headline_table_LR(normalised=True)
# Out:
# <style type="text/css">
# #T_c955a th {
#   background-color: #1d3557;
#   color: white;
#   font-family: Segoe UI, Arial, sans-serif;
#   font-size: 13px;
#   font-weight: bold;
#   padding: 10px 12px;
#   border: 1px solid #d3d3d3;
#   text-align: center;
# }
# #T_c955a td {
#   font-family: Segoe UI, Arial, sans-serif;
#   font-size: 13px;
#   padding: 8px 12px;
#   border: 1px solid #e0e0e0;
#   text-align: center;
# }
# #T_c955a td:first-child {
#   text-align: left;
#   font-weight: bold;
# }
# #T_c955a table {
#   border-collapse: collapse;
#   width: 95%;
#   margin: 15px 0;
# }
# </style>
# <table id="T_c955a">
#   <thead>
#     <tr>
#       <th id="T_c955a_level0_col0" class="col_heading level0 col0" >Ansatz / Baseline</th>
#       <th id="T_c955a_level0_col1" class="col_heading level0 col1" >Macro-F1 (Experte 1)</th>
#       <th id="T_c955a_level0_col2" class="col_heading level0 col2" >Exact Match (Experte 1)</th>
# ...

# %%
import sys
import os
import importlib

sys.path.insert(0, os.path.abspath('.'))

import heatmap_lr
importlib.reload(heatmap_lr)

# 1. Haupt-Heatmap generieren
fig = heatmap_lr.plot_results_heatmap_LR(expert_id=2, metric_type="f1")

# -------------------------------------------------------------------------
# Weitere Varianten (bei Bedarf auskommentieren):
# -------------------------------------------------------------------------
# Exact Match gegen Experte 2:
# fig_exact = plot_results_heatmap_LR(expert_id=2, metric_type="exact")

# Macro-F1 gegen Experte 1:
# fig_exp1 = plot_results_heatmap_LR(expert_id=1, metric_type="f1")
