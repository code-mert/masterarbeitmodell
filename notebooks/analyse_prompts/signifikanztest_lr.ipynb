# %%
import sys
import os

# Pfad-Setup für den Import des Signifikanztest-Moduls
current_dir = os.path.abspath('')
if current_dir not in sys.path:
    sys.path.insert(0, current_dir)

from signifikanztest_lr import compute_significance_lr, print_significance_report

# Statistische Signifikanzanalyse für Zero-Shot vs. 2-Stage CoT im Vergleich zu Experte 2
res = compute_significance_lr(expert_id=2, normalised=True, random_state=42)
print_significance_report(res)
# Out:
#     <div style="background-color: #d4edda; border: 1.5px solid #155724; padding: 14px 18px; border-radius: 8px; margin-bottom: 20px; font-family: 'Segoe UI', Arial, sans-serif;">
#         <h3 style="margin: 0 0 6px 0; color: #155724; font-size: 16px;">📊 Statistische Signifikanzanalyse (Zero-Shot vs. 2-Stage CoT) | Referenz: Experte 2</h3>
#         <p style="margin: 0; font-size: 14px; color: #333333;">
#             <strong>Macro-Ø (Bootstrap 10.000):</strong> CoT − Zero = <strong>+0.03</strong>
#             [95-%-CI: <code>+0.01</code> bis <code>+0.05</code>] &nbsp;|&nbsp;
#             <strong>Signifikant:</strong> <span style="color: #155724; font-weight: bold;">JA (statistisch signifikant)</span>
#         </p>
#     </div>
#         <div style="margin-bottom: 24px; font-family: 'Segoe UI', Arial, sans-serif;">
#             <h4 style="margin: 0 0 10px 0; color: #1d3557; font-size: 15px;">📌 1. Fokus-Kategorien</h4>
# ...
