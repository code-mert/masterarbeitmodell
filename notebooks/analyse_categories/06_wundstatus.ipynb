# %%
import os
from wundstatus_calc import calculate_category_lr_scores
from plot_utils import plot_single_bar_category_comparison

# 1. Berechne Wundstadium L&R F1-Score % (Best-of-Both)
data_stadium_lr = calculate_category_lr_scores("wundstadium", is_phase=True)
save_png = os.path.abspath("../../exports/pngs/wundstadium_lr_performance_comparison.png")
plot_single_bar_category_comparison(
    title="Wundstadium / Wundphase: L&R Experten vs. KI-Ansätze (Best-of-Both F1-Score %)",
    data=data_stadium_lr,
    save_path=save_png
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundstadium_lr_performance_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_nursit_scores
from plot_utils import plot_single_bar_category_comparison

# 2. Berechne Wundstadium NursIT F1-Score % vs. Experte 3
data_stadium_nursit = calculate_category_nursit_scores("wundstadium", is_phase=True)
save_png = os.path.abspath("../../exports/pngs/wundstadium_nursit_performance_comparison.png")
plot_single_bar_category_comparison(
    title="Wundstadium / Wundphase: NursIT Experte vs. KI-Ansätze (F1-Score %)",
    data=data_stadium_nursit,
    save_path=save_png
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundstadium_nursit_performance_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_consensus_scores
from plot_utils import plot_consensus_category_comparison

# 3. Berechne Wundstadium KI-Performance bei Experten-Konsens (41 Wunden)
data_stadium_consensus = calculate_category_consensus_scores("wundstadium", is_phase=True)
save_png = os.path.abspath("../../exports/pngs/wundstadium_consensus_ai_comparison.png")
plot_consensus_category_comparison(
    title="Wundstadium / Wundphase bei Experten-Konsens (41 Wunden - F1-Score %)",
    data=data_stadium_consensus,
    save_path=save_png
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundstadium_consensus_ai_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_lr_scores
from plot_utils import plot_single_bar_category_comparison

# 4. Berechne Wundrand L&R F1-Score % (Best-of-Both)
data_rand_lr = calculate_category_lr_scores("wundrand", is_phase=False)
save_png = os.path.abspath("../../exports/pngs/wundrand_lr_performance_comparison.png")
plot_single_bar_category_comparison(
    title="Wundrand: L&R Experten vs. KI-Ansätze (Best-of-Both F1-Score %)",
    data=data_rand_lr,
    save_path=save_png
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundrand_lr_performance_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_nursit_scores
from plot_utils import plot_single_bar_category_comparison

# 5. Berechne Wundrand NursIT F1-Score % vs. Experte 3
data_rand_nursit = calculate_category_nursit_scores("wundrand", is_phase=False)
save_png = os.path.abspath("../../exports/pngs/wundrand_nursit_performance_comparison.png")
plot_single_bar_category_comparison(
    title="Wundrand: NursIT Experte vs. KI-Ansätze (F1-Score %)",
    data=data_rand_nursit,
    save_path=save_png
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundrand_nursit_performance_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_consensus_scores
from plot_utils import plot_consensus_category_comparison

# 6. Berechne Wundrand KI-Performance bei Experten-Konsens (18 Wunden)
data_rand_consensus = calculate_category_consensus_scores("wundrand", is_phase=False)
save_png = os.path.abspath("../../exports/pngs/wundrand_consensus_ai_comparison.png")
plot_consensus_category_comparison(
    title="Wundrand bei Experten-Konsens (18 Wunden - F1-Score %)",
    data=data_rand_consensus,
    save_path=save_png
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundrand_consensus_ai_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_lr_scores
from plot_utils import plot_single_bar_category_comparison

# 7. Berechne Wundumgebung L&R F1-Score % (Best-of-Both)
data_umgebung_lr = calculate_category_lr_scores("wundumgebung", is_phase=False)
save_png = os.path.abspath("../../exports/pngs/wundumgebung_lr_performance_comparison.png")
plot_single_bar_category_comparison(
    title="Wundumgebung: L&R Experten vs. KI-Ansätze (Best-of-Both F1-Score %)",
    data=data_umgebung_lr,
    save_path=save_png
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundumgebung_lr_performance_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_nursit_scores
from plot_utils import plot_single_bar_category_comparison

# 8. Berechne Wundumgebung NursIT F1-Score % vs. Experte 3
data_umgebung_nursit = calculate_category_nursit_scores("wundumgebung", is_phase=False)
save_png = os.path.abspath("../../exports/pngs/wundumgebung_nursit_performance_comparison.png")
plot_single_bar_category_comparison(
    title="Wundumgebung: NursIT Experte vs. KI-Ansätze (F1-Score %)",
    data=data_umgebung_nursit,
    save_path=save_png
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundumgebung_nursit_performance_comparison.png

# %%
import os
from wundstatus_calc import calculate_category_consensus_scores
from plot_utils import plot_consensus_category_comparison

# 9. Berechne Wundumgebung KI-Performance bei Experten-Konsens (16 Wunden)
data_umgebung_consensus = calculate_category_consensus_scores("wundumgebung", is_phase=False)
save_png = os.path.abspath("../../exports/pngs/wundumgebung_consensus_ai_comparison.png")
plot_consensus_category_comparison(
    title="Wundumgebung bei Experten-Konsens (16 Wunden - F1-Score %)",
    data=data_umgebung_consensus,
    save_path=save_png
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundumgebung_consensus_ai_comparison.png

# %%
import os
from wundstatus_calc import calculate_wundstatus_overall_consensus_scores
from plot_utils import plot_consensus_category_comparison

# 10. Gesamter Wundstatus: Durchschnittlicher F1-Score über alle 3 Kategorien bei Experten-Konsens
data_overall_consensus = calculate_wundstatus_overall_consensus_scores()
save_png = os.path.abspath("../../exports/pngs/wundstatus_overall_consensus_ai_comparison.png")
plot_consensus_category_comparison(
    title="Gesamter Wundstatus: Durchschnittlicher F1-Score über alle 3 Kategorien (Konsens-Wunden)",
    data=data_overall_consensus,
    save_path=save_png
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/wundstatus_overall_consensus_ai_comparison.png
