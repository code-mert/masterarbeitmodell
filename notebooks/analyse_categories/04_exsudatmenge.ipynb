# %%
import os
from exsudat_calc import calculate_exsudat_lr_ordinal_scores
from plot_utils import plot_single_bar_category_comparison

# 1. Berechne Exsudat-Ordinal-Scores für L&R (Experte 1 & Experte 2 Best-of-Both)
data_lr = calculate_exsudat_lr_ordinal_scores()

# Pfad zum Speichern des L&R PNG-Bildes in exports/pngs/
save_png_lr = os.path.abspath("../../exports/pngs/exsudat_lr_performance_comparison.png")

# Erzeuge und zeige den L&R Ordinal-Score-Plot an (% Ordinal Score)
plot_single_bar_category_comparison(
    title="Exsudatmenge: Lohmann & Rauscher Experten vs. KI-Ansätze (Ordinal Score)",
    data=data_lr,
    save_path=save_png_lr
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/exsudat_lr_performance_comparison.png

# %%
import os
from exsudat_calc import calculate_exsudat_nursit_ordinal_scores
from plot_utils import plot_single_bar_category_comparison

# 2. Berechne Exsudat-Ordinal-Scores für NursIT (Experte 3)
data_nursit = calculate_exsudat_nursit_ordinal_scores()

# Pfad zum Speichern des NursIT PNG-Bildes in exports/pngs/
save_png_nursit = os.path.abspath("../../exports/pngs/exsudat_nursit_performance_comparison.png")

# Erzeuge und zeige den NursIT Ordinal-Score-Plot an (% Ordinal Score)
plot_single_bar_category_comparison(
    title="Exsudatmenge: NursIT Experte vs. KI-Ansätze (Ordinal Score)",
    data=data_nursit,
    save_path=save_png_nursit
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/exsudat_nursit_performance_comparison.png

# %%
import os
from exsudat_calc import calculate_exsudat_consensus_ordinal_scores
from plot_utils import plot_consensus_category_comparison

# 3. Berechne KI-Ordinal-Scores bei 100% Experten-Einigkeit (6 Konsens-Wunden)
data_consensus = calculate_exsudat_consensus_ordinal_scores()

# Pfad zum Speichern des Konsens PNG-Bildes in exports/pngs/
save_png_consensus = os.path.abspath("../../exports/pngs/exsudat_consensus_ai_comparison.png")

# Erzeuge und zeige den Konsens Ordinal-Score-Plot an (L&R vs NursIT KI-Ansätze)
plot_consensus_category_comparison(
    title="Exsudatmenge bei 100% Experten-Einigkeit (6 Konsens-Wunden - Ordinal Score)",
    data=data_consensus,
    save_path=save_png_consensus
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/exsudat_consensus_ai_comparison.png
