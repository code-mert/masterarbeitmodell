# %%
import os
from infektion_calc import calculate_infektion_lr_scores
from plot_utils import plot_single_bar_category_comparison

# 1. Berechne L&R Infektionsstatus Performance (Binär: Exact Match %)
data_lr = calculate_infektion_lr_scores()

# Pfad zum Speichern des L&R PNG-Bildes in exports/pngs/
save_png_lr = os.path.abspath("../../exports/pngs/infektion_lr_performance_comparison.png")

# Erzeuge und zeige den L&R Exact-Match-Plot an (Best-of-Both)
plot_single_bar_category_comparison(
    title="Infektionsstatus: Lohmann & Rauscher Experten vs. KI-Ansätze (Best-of-Both Exact Match %)",
    data=data_lr,
    save_path=save_png_lr
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/infektion_lr_performance_comparison.png

# %%
import os
from infektion_calc import calculate_infektion_nursit_scores
from plot_utils import plot_single_bar_category_comparison

# 2. Berechne NursIT Infektionsstatus Performance (3-stufig Ordinal Score %)
data_nursit = calculate_infektion_nursit_scores()

# Pfad zum Speichern des NursIT PNG-Bildes in exports/pngs/
save_png_nursit = os.path.abspath("../../exports/pngs/infektion_nursit_performance_comparison.png")

# Erzeuge und zeige den NursIT Ordinal-Score-Plot an (% Ordinal Score)
plot_single_bar_category_comparison(
    title="Infektionsstatus: NursIT Experte vs. KI-Ansätze (3-stufiger Ordinal Score %)",
    data=data_nursit,
    save_path=save_png_nursit
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/infektion_nursit_performance_comparison.png

# %%
import os
from infektion_calc import calculate_infektion_consensus_scores
from plot_utils import plot_consensus_category_comparison

# 3. Berechne KI-Performance bei Mehrheits-Konsens (2/3 & 3/3 Einigkeit auf Binär gemappt)
data_consensus = calculate_infektion_consensus_scores()

# Pfad zum Speichern des Konsens PNG-Bildes in exports/pngs/
save_png_consensus = os.path.abspath("../../exports/pngs/infektion_consensus_ai_comparison.png")

# Erzeuge und zeige den Konsens-Plot an (58 Mehrheits-Konsens-Wunden)
plot_consensus_category_comparison(
    title="Infektionsstatus bei Experten-Mehrheitskonsens (>= 2/3 Einigkeit - 58 Wunden)",
    data=data_consensus,
    save_path=save_png_consensus
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/infektion_consensus_ai_comparison.png

# %%
import os
from infektion_calc import calculate_spuelloesung_consensus_scores
from plot_utils import plot_consensus_category_comparison

# 4. Berechne Trefferquote der Spüllösung bei den 58 Konsens-Infektionswunden
data_spuelloesung = calculate_spuelloesung_consensus_scores()

# Pfad zum Speichern des Spüllösungs PNG-Bildes in exports/pngs/
save_png_spuelloesung = os.path.abspath("../../exports/pngs/spuelloesung_consensus_ai_comparison.png")

# Erzeuge und zeige den Spüllösungs-Plot an
plot_consensus_category_comparison(
    title="Trefferquote der empfohlenen Spüllösung bei Konsens-Infektionswunden (58 Wunden)",
    data=data_spuelloesung,
    save_path=save_png_spuelloesung
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/spuelloesung_consensus_ai_comparison.png
