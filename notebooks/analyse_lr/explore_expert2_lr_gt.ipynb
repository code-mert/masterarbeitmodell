# %%
import sys
import os
import importlib

# 1. 'notebooks/' (..) hinzufügen für 'utils_notebook'
if os.path.abspath('..') not in sys.path:
    sys.path.append(os.path.abspath('..'))

# 2. Hauptverzeichnis 'Modell/' (../..) hinzufügen für das 'eval' Modul
if os.path.abspath('../..') not in sys.path:
    sys.path.append(os.path.abspath('../..'))

# 3. Falls Module im Jupyter-Cache liegen, diese frisch einlesen
import eval.loaders
import utils_notebook.explore
importlib.reload(eval.loaders)
importlib.reload(utils_notebook.explore)

from utils_notebook.explore import load_gt_dataframe

# Pfad zur LR-GroundTruth (relativ vom Notebook aus)
RAW_CSV_PATH_GT = "../../data/ground_truth/lohmann_rauscher/Experte2_LR_GroundTruth.csv"

# Lädt die rohe GT-CSV als DataFrame (mit Semikolon-Auto-Erkennung)
df_gt_raw = load_gt_dataframe(RAW_CSV_PATH_GT)
df_gt_raw.head(2)
# Out:
#    image_id                                    id  \
# 0  wunde_01  05db697d-c4b4-4505-8cec-2ffd636c00b5
# 1  wunde_02  f4967b67-0fc7-4352-ac80-dbe17625179b
#
#                                 user_id                  updated_at  \
# 0  8ef53b0c-6326-4acf-a373-3578b5ded9de  2026-06-28 04:00:29.737+00
# 1  8ef53b0c-6326-4acf-a373-3578b5ded9de  2026-06-28 04:50:43.585+00
#
#   ist_fertig                                            wundtyp lokalisation  \
# 0      false                    [Postoperative Wunde abdominal]      Abdomen
# 1      false  [Verbrennung 2 und 3 Grades nach 9 er Regel et...  rechte Hand
#
#                          wundstadium                       wundgrund  \
# 0  [Infektion, Nekrose, Fibrinbelag]  stark infiziert, massiv belegt
# 1                                 []           verbrannte  Epidermis
#
#                              wundrand  ...  \
# 0  [Mazeriert, Gerötet / entzündlich]  ...
# 1             [Gerötet / entzündlich]  ...
#
#                                     debridement infektion  \
# 0  [Debrisoft Lolly, Chirurgisches Debridement]        Ja
# 1    [Debrisoft Duo, Chirurgisches Debridement]        Ja
#
#                    spuelloesung                 praeferenz_produkt  \
# 0  [Antimikrobielle Spüllösung]                    [Suprasorb CNP]
# 1  [Antimikrobielle Spüllösung]  [Suprasorb X + PHMB, Solvaline N]
#
#     alternative_produkt ergaenzende_produkte_praeferenz  \
# 0  [Suprasorb X + PHMB]
# 1       [Suprasorb CNP]
#
#   ergaenzende_produkte_alternativ kompression_indiziert kompression_produkte  \
# 0                                                  Nein                   []
# 1                                                  Nein                   []
#
#                                     einschraenkungen
# 0  Nach chirurgischer Sanierung und antiinfektive...
# 1
#
# [2 rows x 24 columns]

# %%
from utils_notebook.explore import explore_answers_interactive

# Zeigt alle Antworten nach Wundnummer an
explore_answers_interactive(df_gt_raw, label="Kategorie")
# Out:
# interactive(children=(Dropdown(description='Kategorie:', index=18, options=('alternative_produkt', 'auffaellig…

# %%
from utils_notebook.explore import explore_distributions_interactive

# Zeigt Häufigkeiten und wie viele unterschiedliche Antworten existieren
explore_distributions_interactive(df_gt_raw, label="Kategorie")
# Out:
# interactive(children=(Dropdown(description='Kategorie:', index=18, options=('alternative_produkt', 'auffaellig…

# %% [markdown]
# # Phase 2

# %%
from utils_notebook.clean import normalize_gt_file

NORM_CSV_PATH_GT = "../data/ground_truth/allgemeine_verbandsklassen_normalised.csv"
# Normalisierung ausführen und als neue CSV abspeichern
normalize_gt_file(RAW_CSV_PATH_GT, NORM_CSV_PATH_GT)
# Out:
# Normalisierte Datei erfolgreich erstellt: ../data/ground_truth/allgemeine_verbandsklassen_normalised.csv

# %%
from utils_notebook.explore import load_gt_dataframe, explore_answers_interactive
# Normalisiertes DataFrame laden und anzeigen
df_gt_norm = load_gt_dataframe(NORM_CSV_PATH_GT)
explore_answers_interactive(df_gt_norm, label="Kategorie (Norm)")
# Out:
# interactive(children=(Dropdown(description='Kategorie (Norm):', index=18, options=('alternative_produkt', 'ant…

# %%
from utils_notebook.explore import explore_distributions_interactive
# Verteilung der normalisierten Antworten anzeigen
explore_distributions_interactive(df_gt_norm, label="Kategorie")
# Out:
# interactive(children=(Dropdown(description='Kategorie:', index=18, options=('alternative_produkt', 'antimikrob…
