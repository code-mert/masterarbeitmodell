# %% [markdown]
# # Kategorie: Primärverband
# Systematischer Leistungsvergleich für den Primärverband auf **Level 1 (Produkt-Ebene)**, **Level 2 (Unterkategorie-Ebene)**, **Level 2 bei ≥ 80% Experten-Einigkeit** und **Level 3 (Verbandsklassen-Ebene)** unter Verwendung von Best-of-Both (2 Experten), Produktpaar-Baselines und Inter-Rater-Agreement.

# %%
import os
import sys

# Add path for imports
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.insert(0, os.path.join(BASE_DIR, "notebooks", "analyse_categories"))

from primaerverband_calc import (
    plot_primaerverband_lr_level1,
    plot_primaerverband_lr_level2,
    plot_primaerverband_lr_level2_high_agreement,
    plot_primaerverband_level3_combined
)

# %%
# Plot 1: L&R Best-of-Both auf Level 1 (Produkt-Ebene - 15 Produkte)
plot_primaerverband_lr_level1(save_path="../../exports/pngs/primaerverband_lr_level1_performance_comparison.png");

# %%
# Plot 2: L&R Best-of-Both auf Level 2 (Unterkategorie-Ebene)
plot_primaerverband_lr_level2(save_path="../../exports/pngs/primaerverband_lr_level2_performance_comparison.png");

# %%
# Plot 3: L&R Best-of-Both auf Level 2 (Unterkategorie-Ebene) NUR auf Wunden mit ≥ 80% Experten-Einigkeit
plot_primaerverband_lr_level2_high_agreement(threshold=0.8, save_path="../../exports/pngs/primaerverband_lr_level2_high_agreement_performance_comparison.png");

# %%
# Plot 4: Combined Evaluation auf Level 3 (Verbandsklassen-Ebene - L&R und NursIT)
plot_primaerverband_level3_combined(save_path="../../exports/pngs/primaerverband_level3_combined_performance_comparison.png");
