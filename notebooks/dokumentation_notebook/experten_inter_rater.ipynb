# %% [markdown]
# # Experten Inter-Rater-Reliabilität (Experte 1 vs. Experte 2)
#
# Dieses Notebook ruft den Inter-Rater-Plot aus der Datei `plot_inter_rater.py` auf.

# %%
import sys
import os

# Aktuelles Verzeichnis zum Pfad hinzufügen
sys.path.insert(0, os.path.abspath('.'))

from plot_inter_rater import plot_expert_inter_rater

# Plot anzeigen
plot_expert_inter_rater()
