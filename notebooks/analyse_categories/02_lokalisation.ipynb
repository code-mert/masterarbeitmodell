# %%
import os
from lokalisation_calc import calculate_lokalisation_lr_scores
from plot_utils import plot_single_bar_category_comparison

# 1. Berechne Lokalisation-Scores für L&R (Experte 1 & Experte 2)
data_lr = calculate_lokalisation_lr_scores()

# Pfad zum Speichern des L&R PNG-Bildes in exports/pngs/
save_png_lr = os.path.abspath("../../exports/pngs/lokalisation_lr_performance_comparison.png")

# Erzeuge und zeige den L&R Plot an (Wundanzahl & Prozent)
plot_single_bar_category_comparison(
    title="Wundlokalisation: Lohmann & Rauscher Experten vs. KI-Ansätze",
    data=data_lr,
    save_path=save_png_lr
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/lokalisation_lr_performance_comparison.png

# %%
import os
from lokalisation_calc import calculate_lokalisation_nursit_scores
from plot_utils import plot_single_bar_category_comparison

# 2. Berechne Lokalisation-Scores für NursIT (Experte 3, ohne Inter-Rater)
data_nursit = calculate_lokalisation_nursit_scores()

# Pfad zum Speichern des NursIT PNG-Bildes in exports/pngs/
save_png_nursit = os.path.abspath("../../exports/pngs/lokalisation_nursit_performance_comparison.png")

# Erzeuge und zeige den NursIT Plot an (Wundanzahl & Prozent)
plot_single_bar_category_comparison(
    title="Wundlokalisation: NursIT Experte vs. KI-Ansätze",
    data=data_nursit,
    save_path=save_png_nursit
)
# Out:
# Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/lokalisation_nursit_performance_comparison.png

# %%
import os
from lokalisation_calc import calculate_lokalisation_consensus_scores
from plot_utils import plot_consensus_category_comparison

# 3. Berechne KI-Scores bei 100% Experten-Einigkeit (40 Konsens-Wunden)
data_consensus = calculate_lokalisation_consensus_scores()

# Pfad zum Speichern des Konsens PNG-Bildes in exports/pngs/
save_png_consensus = os.path.abspath("../../exports/pngs/lokalisation_consensus_ai_comparison.png")

# Erzeuge und zeige den Konsens-Plot an (L&R vs NursIT KI-Ansätze)
plot_consensus_category_comparison(
    title="Wundlokalisation bei 100% Experten-Einigkeit (40 Konsens-Wunden)",
    data=data_consensus,
    save_path=save_png_consensus
)
# Out:
# Konsens-Plot erfolgreich gespeichert unter: /Users/mertakdemir/Developer/uni/Modell/exports/pngs/lokalisation_consensus_ai_comparison.png
