# %%
# Qualitative Analyse: Primärverband
# Dieses Notebook vergleicht alle Roh- und Normalisierungs-Antworten der Kategorie Primärverband
# Beide Antwortsets (Präferenz und Alternativ) werden in den Tabellen untereinander mit Trennlinie dargestellt.

import sys
import os
import pandas as pd
from IPython.display import display

# Pfad-Setup für Helper Modul
sys.path.insert(0, os.path.abspath('.'))
import category_loader

# Tabellen für Primärverband laden (Roh-Antworten & Normalisierte Antworten)
df_raw, df_norm = category_loader.get_category_tables('primärverband')

# Layout-Einstellungen zur vollständigen Textanzeige
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Legende zur Farbcodierung anzeigen
category_loader.display_legend()
# Out:
#     <div style='margin-bottom: 14px; font-family: sans-serif; font-size: 13px; line-height: 2.0; background: #ffffff; padding: 12px; border-radius: 6px; border: 1px solid #dee2e6;'>
#         <b style='color: #111;'>Legende & Offizielle Evaluation (eval/metrics.py):</b><br/>
#         <span style='background-color: #eebefa; color: #360745; padding: 4px 8px; border-radius: 4px; font-weight: bold; margin-right: 8px;'>🟣 Lila</span> Exakter Match (Exact / Best-Path F1 = 100%) mit <b>BEIDEN Experten</b><br/>
#         <span style='background-color: #c3fae8; color: #044229; padding: 4px 8px; border-radius: 4px; font-weight: bold; margin-right: 8px;'>🟢 Grün</span> Exakter Match mit <b>Experte 1</b><br/>
#         <span style='background-color: #d0ebff; color: #002b49; padding: 4px 8px; border-radius: 4px; font-weight: bold; margin-right: 8px;'>🔵 Blau</span> Exakter Match mit <b>Experte 2</b><br/>
#         <span style='background-color: #fff3bf; color: #594200; padding: 4px 8px; border-radius: 4px; font-weight: bold; margin-right: 8px;'>🟠 Orange</span> <b>Teilweiser Match</b> (F1 > 0% / Schnittmenge vorhanden)<br/>
#         <span style='background-color: #ffe3e3; color: #7a0000; padding: 4px 8px; border-radius: 4px; font-weight: bold; margin-right: 8px;'>🔴 Rot</span> <b>Keine Übereinstimmung</b> (F1 = 0%)<br/>
#         <hr style='border: none; border-top: 1px solid #eee; margin: 8px 0;'/>
#         <span style='background-color: #d3f9d8; color: #083e12; padding: 4px 8px; border-radius: 4px; font-weight: bold; margin-right: 8px;'>Experte 1 Spalte</span> Ground Truth Experte 1 (Oben: Präferenz / Unten: Alternativ)<br/>
#         <span style='background-color: #d0ebff; color: #002b49; padding: 4px 8px; border-radius: 4px; font-weight: bold; margin-right: 8px;'>Experte 2 Spalte</span> Ground Truth Experte 2 (Oben: Präferenz / Unten: Alternativ)
#     </div>

# %%
# 1. F1-Score Auswertung: Ungruppiert vs. Produktfamilie (Baseline & Experten-Konsens)
print("=== F1-SCORE VERGLEICH: UNGRUPPIERT VS. PRODUKTFAMILIE ===")
display(category_loader.evaluate_primaerverband_grouped())
# Out:
# === F1-SCORE VERGLEICH: UNGRUPPIERT VS. PRODUKTFAMILIE ===
# <style type="text/css">
# #T_e4841 th {
#   background-color: #1e293b;
#   color: #ffffff;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_e4841 td {
#   padding: 8px 12px;
#   font-size: 13px;
#   text-align: center;
# }
# #T_e4841 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# </style>
# <table id="T_e4841">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4841_level0_col0" class="col_heading level0 col0" >Modell / Ansatz</th>
#       <th id="T_e4841_level0_col1" class="col_heading level0 col1" >Exp 1 (Ungruppiert)</th>
#       <th id="T_e4841_level0_col2" class="col_heading level0 col2" >Exp 1 (Produktfamilie)</th>
#       <th id="T_e4841_level0_col3" class="col_heading level0 col3" >Δ Exp 1</th>
#       <th id="T_e4841_level0_col4" class="col_heading level0 col4" >Exp 2 (Ungruppiert)</th>
#       <th id="T_e4841_level0_col5" class="col_heading level0 col5" >Exp 2 (Produktfamilie)</th>
#       <th id="T_e4841_level0_col6" class="col_heading level0 col6" >Δ Exp 2</th>
#       <th id="T_e4841_level0_col7" class="col_heading level0 col7" >Best-of-Both (Ungruppiert)</th>
#       <th id="T_e4841_level0_col8" class="col_heading level0 col8" >Best-of-Both (Produktfamilie)</th>
#       <th id="T_e4841_level0_col9" class="col_heading level0 col9" >Δ Best-of-Both</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4841_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4841_row0_col0" class="data row0 col0" >Baseline (Majority)</td>
#       <td id="T_e4841_row0_col1" class="data row0 col1" >28.3%</td>
#       <td id="T_e4841_row0_col2" class="data row0 col2" >41.4%</td>
#       <td id="T_e4841_row0_col3" class="data row0 col3" >+13.1%</td>
#       <td id="T_e4841_row0_col4" class="data row0 col4" >46.7%</td>
#       <td id="T_e4841_row0_col5" class="data row0 col5" >56.9%</td>
#       <td id="T_e4841_row0_col6" class="data row0 col6" >+10.3%</td>
#       <td id="T_e4841_row0_col7" class="data row0 col7" >53.6%</td>
#       <td id="T_e4841_row0_col8" class="data row0 col8" >68.6%</td>
#       <td id="T_e4841_row0_col9" class="data row0 col9" >+15.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e4841_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e4841_row1_col0" class="data row1 col0" >Zero-Shot</td>
#       <td id="T_e4841_row1_col1" class="data row1 col1" >16.4%</td>
#       <td id="T_e4841_row1_col2" class="data row1 col2" >35.3%</td>
#       <td id="T_e4841_row1_col3" class="data row1 col3" >+18.9%</td>
#       <td id="T_e4841_row1_col4" class="data row1 col4" >23.7%</td>
#       <td id="T_e4841_row1_col5" class="data row1 col5" >59.4%</td>
#       <td id="T_e4841_row1_col6" class="data row1 col6" >+35.7%</td>
#       <td id="T_e4841_row1_col7" class="data row1 col7" >31.6%</td>
#       <td id="T_e4841_row1_col8" class="data row1 col8" >62.1%</td>
#       <td id="T_e4841_row1_col9" class="data row1 col9" >+30.5%</td>
#     </tr>
#     <tr>
#       <th id="T_e4841_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e4841_row2_col0" class="data row2 col0" >Few-Shot</td>
#       <td id="T_e4841_row2_col1" class="data row2 col1" >17.5%</td>
#       <td id="T_e4841_row2_col2" class="data row2 col2" >37.4%</td>
#       <td id="T_e4841_row2_col3" class="data row2 col3" >+19.9%</td>
#       <td id="T_e4841_row2_col4" class="data row2 col4" >27.3%</td>
#       <td id="T_e4841_row2_col5" class="data row2 col5" >58.1%</td>
#       <td id="T_e4841_row2_col6" class="data row2 col6" >+30.8%</td>
#       <td id="T_e4841_row2_col7" class="data row2 col7" >33.8%</td>
#       <td id="T_e4841_row2_col8" class="data row2 col8" >63.1%</td>
#       <td id="T_e4841_row2_col9" class="data row2 col9" >+29.3%</td>
#     </tr>
#     <tr>
#       <th id="T_e4841_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e4841_row3_col0" class="data row3 col0" >Two-Stage</td>
#       <td id="T_e4841_row3_col1" class="data row3 col1" >24.6%</td>
#       <td id="T_e4841_row3_col2" class="data row3 col2" >45.6%</td>
#       <td id="T_e4841_row3_col3" class="data row3 col3" >+20.9%</td>
#       <td id="T_e4841_row3_col4" class="data row3 col4" >36.5%</td>
#       <td id="T_e4841_row3_col5" class="data row3 col5" >66.3%</td>
#       <td id="T_e4841_row3_col6" class="data row3 col6" >+29.8%</td>
#       <td id="T_e4841_row3_col7" class="data row3 col7" >42.2%</td>
#       <td id="T_e4841_row3_col8" class="data row3 col8" >71.1%</td>
#       <td id="T_e4841_row3_col9" class="data row3 col9" >+28.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e4841_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e4841_row4_col0" class="data row4 col0" >Experten-Übereinstimmung (Exp 1 vs Exp 2)</td>
#       <td id="T_e4841_row4_col1" class="data row4 col1" >46.2%</td>
#       <td id="T_e4841_row4_col2" class="data row4 col2" >55.5%</td>
#       <td id="T_e4841_row4_col3" class="data row4 col3" >+9.3%</td>
#       <td id="T_e4841_row4_col4" class="data row4 col4" >46.2%</td>
#       <td id="T_e4841_row4_col5" class="data row4 col5" >55.5%</td>
#       <td id="T_e4841_row4_col6" class="data row4 col6" >+9.3%</td>
#       <td id="T_e4841_row4_col7" class="data row4 col7" >46.2%</td>
#       <td id="T_e4841_row4_col8" class="data row4 col8" >55.5%</td>
#       <td id="T_e4841_row4_col9" class="data row4 col9" >+9.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 2. Roh-Antworten (Primärverband - Raw)
display(category_loader.style_category_table(df_raw, 'primärverband'))
# Out:
# <style type="text/css">
# #T_f79e8 th {
#   background-color: #343a40;
#   color: #ffffff;
#   font-weight: bold;
#   text-align: center;
#   padding: 8px;
# }
# #T_f79e8 td {
#   padding: 6px 10px;
#   font-size: 13px;
# }
# #T_f79e8 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_f79e8_row0_col0, #T_f79e8_row1_col0, #T_f79e8_row2_col0, #T_f79e8_row3_col0, #T_f79e8_row4_col0, #T_f79e8_row5_col0, #T_f79e8_row6_col0, #T_f79e8_row7_col0, #T_f79e8_row8_col0, #T_f79e8_row9_col0, #T_f79e8_row10_col0, #T_f79e8_row11_col0, #T_f79e8_row12_col0, #T_f79e8_row13_col0, #T_f79e8_row14_col0, #T_f79e8_row15_col0, #T_f79e8_row16_col0, #T_f79e8_row17_col0, #T_f79e8_row18_col0, #T_f79e8_row19_col0, #T_f79e8_row20_col0, #T_f79e8_row21_col0, #T_f79e8_row22_col0, #T_f79e8_row23_col0, #T_f79e8_row24_col0, #T_f79e8_row25_col0, #T_f79e8_row26_col0, #T_f79e8_row27_col0, #T_f79e8_row28_col0, #T_f79e8_row29_col0, #T_f79e8_row30_col0, #T_f79e8_row31_col0, #T_f79e8_row32_col0, #T_f79e8_row33_col0, #T_f79e8_row34_col0, #T_f79e8_row35_col0, #T_f79e8_row36_col0, #T_f79e8_row37_col0, #T_f79e8_row38_col0, #T_f79e8_row39_col0, #T_f79e8_row40_col0, #T_f79e8_row41_col0, #T_f79e8_row42_col0, #T_f79e8_row43_col0, #T_f79e8_row44_col0, #T_f79e8_row45_col0, #T_f79e8_row46_col0, #T_f79e8_row47_col0, #T_f79e8_row48_col0, #T_f79e8_row49_col0, #T_f79e8_row50_col0, #T_f79e8_row51_col0, #T_f79e8_row52_col0, #T_f79e8_row53_col0, #T_f79e8_row54_col0, #T_f79e8_row55_col0, #T_f79e8_row56_col0, #T_f79e8_row57_col0, #T_f79e8_row58_col0, #T_f79e8_row59_col0 {
#   background-color: #e9ecef;
#   background-color: #ffe3e3;
#   color: #7a0000;
#   font-weight: bold;
#   opacity: 1.0;
# }
# #T_f79e8_row2_col3, #T_f79e8_row3_col3, #T_f79e8_row4_col4, #T_f79e8_row4_col5, #T_f79e8_row9_col4, #T_f79e8_row9_col5, #T_f79e8_row10_col3, #T_f79e8_row10_col4, #T_f79e8_row10_col5, #T_f79e8_row11_col4, #T_f79e8_row14_col3, #T_f79e8_row16_col3, #T_f79e8_row16_col4, #T_f79e8_row16_col5, #T_f79e8_row18_col4, #T_f79e8_row19_col3, #T_f79e8_row19_col4, #T_f79e8_row19_col5, #T_f79e8_row20_col4, #T_f79e8_row20_col5, #T_f79e8_row22_col4, #T_f79e8_row23_col4, #T_f79e8_row25_col3, #T_f79e8_row25_col4, #T_f79e8_row25_col5, #T_f79e8_row26_col5, #T_f79e8_row27_col3, #T_f79e8_row27_col4, #T_f79e8_row27_col5, #T_f79e8_row29_col4, #T_f79e8_row29_col5, #T_f79e8_row30_col5, #T_f79e8_row34_col4, #T_f79e8_row35_col4, #T_f79e8_row35_col5, #T_f79e8_row36_col3, #T_f79e8_row36_col4, #T_f79e8_row36_col5, #T_f79e8_row38_col3, #T_f79e8_row38_col5, #T_f79e8_row40_col4, #T_f79e8_row41_col4, #T_f79e8_row41_col5, #T_f79e8_row42_col3, #T_f79e8_row42_col4, #T_f79e8_row42_col5, #T_f79e8_row43_col3, #T_f79e8_row43_col4, #T_f79e8_row43_col5, #T_f79e8_row44_col3, #T_f79e8_row46_col3, #T_f79e8_row46_col4, #T_f79e8_row46_col5, #T_f79e8_row47_col4, #T_f79e8_row47_col5, #T_f79e8_row48_col4, #T_f79e8_row48_col5, #T_f79e8_row50_col3, #T_f79e8_row50_col4, #T_f79e8_row50_col5, #T_f79e8_row51_col5, #T_f79e8_row52_col4, #T_f79e8_row52_col5, #T_f79e8_row53_col3, #T_f79e8_row53_col4, #T_f79e8_row53_col5, #T_f79e8_row54_col4, #T_f79e8_row55_col4, #T_f79e8_row56_col3, #T_f79e8_row56_col4, #T_f79e8_row57_

# %%
# 3. Normalisierte Antworten (Primärverband - Normalised)
display(category_loader.style_category_table(df_norm, 'primärverband'))
# Out:
# <style type="text/css">
# #T_a63b3 th {
#   background-color: #343a40;
#   color: #ffffff;
#   font-weight: bold;
#   text-align: center;
#   padding: 8px;
# }
# #T_a63b3 td {
#   padding: 6px 10px;
#   font-size: 13px;
# }
# #T_a63b3 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_a63b3_row0_col0, #T_a63b3_row1_col0, #T_a63b3_row2_col0, #T_a63b3_row3_col0, #T_a63b3_row4_col0, #T_a63b3_row5_col0, #T_a63b3_row6_col0, #T_a63b3_row7_col0, #T_a63b3_row8_col0, #T_a63b3_row9_col0, #T_a63b3_row10_col0, #T_a63b3_row11_col0, #T_a63b3_row12_col0, #T_a63b3_row13_col0, #T_a63b3_row14_col0, #T_a63b3_row15_col0, #T_a63b3_row16_col0, #T_a63b3_row17_col0, #T_a63b3_row18_col0, #T_a63b3_row19_col0, #T_a63b3_row20_col0, #T_a63b3_row21_col0, #T_a63b3_row22_col0, #T_a63b3_row23_col0, #T_a63b3_row24_col0, #T_a63b3_row25_col0, #T_a63b3_row26_col0, #T_a63b3_row27_col0, #T_a63b3_row28_col0, #T_a63b3_row29_col0, #T_a63b3_row30_col0, #T_a63b3_row31_col0, #T_a63b3_row32_col0, #T_a63b3_row33_col0, #T_a63b3_row34_col0, #T_a63b3_row35_col0, #T_a63b3_row36_col0, #T_a63b3_row37_col0, #T_a63b3_row38_col0, #T_a63b3_row39_col0, #T_a63b3_row40_col0, #T_a63b3_row41_col0, #T_a63b3_row42_col0, #T_a63b3_row43_col0, #T_a63b3_row44_col0, #T_a63b3_row45_col0, #T_a63b3_row46_col0, #T_a63b3_row47_col0, #T_a63b3_row48_col0, #T_a63b3_row49_col0, #T_a63b3_row50_col0, #T_a63b3_row51_col0, #T_a63b3_row52_col0, #T_a63b3_row53_col0, #T_a63b3_row54_col0, #T_a63b3_row55_col0, #T_a63b3_row56_col0, #T_a63b3_row57_col0, #T_a63b3_row58_col0, #T_a63b3_row59_col0 {
#   background-color: #e9ecef;
#   color: #111111;
#   font-weight: bold;
#   border-right: 2px solid #dee2e6;
# }
# #T_a63b3_row0_col1, #T_a63b3_row1_col1, #T_a63b3_row2_col1, #T_a63b3_row3_col1, #T_a63b3_row4_col1, #T_a63b3_row5_col1, #T_a63b3_row6_col1, #T_a63b3_row7_col1, #T_a63b3_row8_col1, #T_a63b3_row9_col1, #T_a63b3_row10_col1, #T_a63b3_row11_col1, #T_a63b3_row12_col1, #T_a63b3_row13_col1, #T_a63b3_row14_col1, #T_a63b3_row15_col1, #T_a63b3_row16_col1, #T_a63b3_row17_col1, #T_a63b3_row18_col1, #T_a63b3_row19_col1, #T_a63b3_row20_col1, #T_a63b3_row21_col1, #T_a63b3_row22_col1, #T_a63b3_row23_col1, #T_a63b3_row24_col1, #T_a63b3_row25_col1, #T_a63b3_row26_col1, #T_a63b3_row27_col1, #T_a63b3_row28_col1, #T_a63b3_row29_col1, #T_a63b3_row30_col1, #T_a63b3_row31_col1, #T_a63b3_row32_col1, #T_a63b3_row33_col1, #T_a63b3_row34_col1, #T_a63b3_row35_col1, #T_a63b3_row36_col1, #T_a63b3_row37_col1, #T_a63b3_row38_col1, #T_a63b3_row39_col1, #T_a63b3_row40_col1, #T_a63b3_row41_col1, #T_a63b3_row42_col1, #T_a63b3_row43_col1, #T_a63b3_row44_col1, #T_a63b3_row45_col1, #T_a63b3_row46_col1, #T_a63b3_row47_col1, #T_a63b3_row48_col1, #T_a63b3_row49_col1, #T_a63b3_row50_col1, #T_a63b3_row51_col1, #T_a63b3_row52_col1, #T_a63b3_row53_col1, #T_a63b3_row54_col1, #T_a63b3_row55_col1, #T_a63b3_row56_col1, #T_a63b3_row57_col1, #T_a63b3_row58_col1, #T_a63b3_row59_col1 {
#   background-color: #d3f9d8;
#   color: #083e12;
#   font-weight: bold;
#   opacity: 1.0;
# }
# #T
3, #T_a63b3_row48_col4, #T_a63b3_row48_col5, #T_a63b3_row50_col3, #T_a63b3_row50_col4, #T_a63b3_row50_col5, #T_a63b3_row51_col5, #T_a63b3_row52_col3, #T_a63b3_row52_col4, #T_a63b3_row52_col5, #T_a63b3_row53_col3, #T_a63b3_row53_col4, #T_a63b3_row53_col5, #T_a63b3_row54_col3, #T_a63b3_row54_col4, #T_a63b3_row54_col5, #T_a63b3_row55_col4, #T_a63b3_row56_col3, #T_a63b3_row56_col4, #T_a63b3_row56_col5, #T_a63b3_row57_col3, #T_a63b3_row57_col4, #T_a63b3_row57_col5, #T_a63b3_row58_col3, #T_a63b3_row58

# %%
# 4. Fehlschlag-Tabelle (Wo alle 3 LLMs gefehlt haben)
df_failed_raw, df_failed_norm = category_loader.get_failed_cases('primärverband')
print(f"Anzahl kompletter Fehlschläge aller 3 LLMs bei Primärverband: {len(df_failed_norm)} von 60")
display(category_loader.style_category_table(df_failed_norm, 'primärverband'))
# Out:
# Anzahl kompletter Fehlschläge aller 3 LLMs bei Primärverband: 15 von 60
# <style type="text/css">
# #T_7c4d4 th {
#   background-color: #343a40;
#   color: #ffffff;
#   font-weight: bold;
#   text-align: center;
#   padding: 8px;
# }
# #T_7c4d4 td {
#   padding: 6px 10px;
#   font-size: 13px;
# }
# #T_7c4d4 table {
#   border-collapse: collapse;
#   width: 100%;
# }
# #T_7c4d4_row0_col0, #T_7c4d4_row1_col0, #T_7c4d4_row2_col0, #T_7c4d4_row3_col0, #T_7c4d4_row4_col0, #T_7c4d4_row5_col0, #T_7c4d4_row6_col0, #T_7c4d4_row7_col0, #T_7c4d4_row8_col0, #T_7c4d4_row9_col0, #T_7c4d4_row10_col0, #T_7c4d4_row11_col0, #T_7c4d4_row12_col0, #T_7c4d4_row13_col0, #T_7c4d4_row14_col0 {
#   background-color: #e9ecef;
#   color: #111111;
#   font-weight: bold;
#   border-right: 2px solid #dee2e6;
# }
# #T_7c4d4_row0_col1, #T_7c4d4_row1_col1, #T_7c4d4_row2_col1, #T_7c4d4_row3_col1, #T_7c4d4_row4_col1, #T_7c4d4_row5_col1, #T_7c4d4_row6_col1, #T_7c4d4_row7_col1, #T_7c4d4_row8_col1, #T_7c4d4_row9_col1, #T_7c4d4_row10_col1, #T_7c4d4_row11_col1, #T_7c4d4_row12_col1, #T_7c4d4_row13_col1, #T_7c4d4_row14_col1 {
#   background-color: #d3f9d8;
#   color: #083e12;
#   font-weight: bold;
#   opacity: 1.0;
# }
# #T_7c4d4_row0_col2, #T_7c4d4_row1_col2, #T_7c4d4_row2_col2, #T_7c4d4_row3_col2, #T_7c4d4_row4_col2, #T_7c4d4_row5_col2, #T_7c4d4_row6_col2, #T_7c4d4_row7_col2, #T_7c4d4_row8_col2, #T_7c4d4_row9_col2, #T_7c4d4_row10_col2, #T_7c4d4_row11_col2, #T_7c4d4_row12_col2, #T_7c4d4_row13_col2, #T_7c4d4_row14_col2 {
#   background-color: #d0ebff;
#   color: #002b49;
#   font-weight: bold;
#   opacity: 1.0;
# }
# #T_7c4d4_row0_col3, #T_7c4d4_row0_col4, #T_7c4d4_row0_col5, #T_7c4d4_row1_col3, #T_7c4d4_row1_col4, #T_7c4d4_row1_col5, #T_7c4d4_row2_col3, #T_7c4d4_row2_col4, #T_7c4d4_row2_col5, #T_7c4d4_row3_col3, #T_7c4d4_row3_col4, #T_7c4d4_row3_col5, #T_7c4d4_row4_col3, #T_7c4d4_row4_col4, #T_7c4d4_row4_col5, #T_7c4d4_row5_col3, #T_7c4d4_row5_col4, #T_7c4d4_row5_col5, #T_7c4d4_row6_col3, #T_7c4d4_row6_col4, #T_7c4d4_row6_col5, #T_7c4d4_row7_col3, #T_7c4d4_row7_col4, #T_7c4d4_row7_col5, #T_7c4d4_row8_col3, #T_7c4d4_row8_col4, #T_7c4d4_row8_col5, #T_7c4d4_row9_col3, #T_7c4d4_row9_col4, #T_7c4d4_row9_col5, #T_7c4d4_row10_col3, #T_7c4d4_row10_col4, #T_7c4d4_row10_col5, #T_7c4d4_row11_col3, #T_7c4d4_row11_col4, #T_7c4d4_row11_col5, #T_7c4d4_row12_col3, #T_7c4d4_row12_col4, #T_7c4d4_row12_col5, #T_7c4d4_row13_col3, #T_7c4d4_row13_col4, #T_7c4d4_row13_col5, #T_7c4d4_row14_col3, #T_7c4d4_row14_col4, #T_7c4d4_row14_col5 {
#   background-color: #ffe3e3;
#   color: #7a0000;
#   font-weight: bold;
#   opacity: 1.0;
# }
# </style>
# <table id="T_7c4d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c4d4_level0_col0" class="col_heading level0 col0" >image_id</th>
#       <th id="T_7c4d4_level0_col1" class="col_heading level0 col1" >Experte 1</th>
#       <th id="T_7c4d4_level0_col2" class="col_heading level0 col2" >Experte 2</th>
#       <th id="T_7c4d4_level0_col3" class="col_heading level0 col3" >Zero-Shot</th>
#       <th id="T_7c4d4_level0_col4" class="col_heading level0 col4" >Few-Shot</th>
#       <th id="T_7c4d4_level0_col5" class="col_heading level0 col5" >Two-Stage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c4d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c4d4_row0_col0" class="data row0 col0" >wunde_01</td>
#       <td id="T_7c4d4_row0_col1" class="data row0 col1" ><div>["Suprasorb CNP"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>—</div></td>
#       <td id="T_7c4d4_row0_col2" class="data row0 col2" ><div>["Suprasorb CNP"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb X + PHMB"]</div></td>
#       <td id="T_7c4d4_row0_col3" class="data row0 col3" ><div>["Suprasorb A + Ag", "Vliwasorb Pro"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Vliwaktiv Ag"]</div></td>
#       <td id="T_7c4d4_row0_col4" class="data row0 col4" ><div>["Suprasorb A + Ag", "Vliwasorb Pro"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Vliwaktiv Ag", "Vliwazell Pro"]</div></td>
#       <td id="T_7c4d4_row0_col5" class="data row0 col5" ><div>["Suprasorb A + Ag", "Vliwasorb Pro"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Vliwaktiv Ag", "Vliwasorb Pro"]</div></td>
#     </tr>
#     <tr>
#       <th id="T_7c4d4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c4d4_row1_col0" class="data row1 col0" >wunde_02</td>
#       <td id="T_7c4d4_row1_col1" class="data row1 col1" ><div>["Solvaline N", "Suprasorb P + PHMB"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>—</div></td>
#       <td id="T_7c4d4_row1_col2" class="data row1 col2" ><div>["Solvaline N", "Suprasorb X + PHMB"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb CNP"]</div></td>
#       <td id="T_7c4d4_row1_col3" class="data row1 col3" ><div>["Suprasorb P Sensitive", "Suprasorb X"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Metalline Kompresse", "Vliwazell"]</div></td>
#       <td id="T_7c4d4_row1_col4" class="data row1 col4" ><div>["Suprasorb X"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Metalline Kompresse"]</div></td>
#       <td id="T_7c4d4_row1_col5" class="data row1 col5" ><div>["Lomatuell Pro", "Suprasorb P Sensitive"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb X Pro"]</div></td>
#     </tr>
#     <tr>
#       <th id="T_7c4d4_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_7c4d4_row2_col0" class="data row2 col0" >wunde_06</td>
#       <td id="T_7c4d4_row2_col1" class="data row2 col1" ><div>["Solvaline N", "Suprasorb X + PHMB"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>—</div></td>
#       <td id="T_7c4d4_row2_col2" class="data row2 col2" ><div>["Solvaline N", "Suprasorb P + PHMB"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>—</div></td>
#       <td id="T_7c4d4_row2_col3" class="data row2 col3" ><div>["Suprasorb P Sensitive", "Suprasorb X Pro"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Lomatuell Pro", "Suprasorb P Sensiflex"]</div></td>
#       <td id="T_7c4d4_row2_col4" class="data row2 col4" ><div>["Lomatuell Pro", "Suprasorb P Sensitive"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb P Sensiflex", "Suprasorb X"]</div></td>
#       <td id="T_7c4d4_row2_col5" class="data row2 col5" ><div>["Suprasorb X Pro"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb H", "Suprasorb P Sensitive"]</div></td>
#     </tr>
#     <tr>
#       <th id="T_7c4d4_level0_row3" class="row_heading level0 row3" >6</th>
#       <td id="T_7c4d4_row3_col0" class="data row3 col0" >wunde_07</td>
#       <td id="T_7c4d4_row3_col1" class="data row3 col1" ><div>["Suprasorb CNP"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>—</div></td>
#       <td id="T_7c4d4_row3_col2" class="data row3 col2" ><div>["Lomatuell Pro", "Suprasorb CNP"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Vliwazell Pro"]</div></td>
#       <td id="T_7c4d4_row3_col3" class="data row3 col3" ><div>["Suprasorb Liquacel Pro", "Suprasorb P"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb A Pro", "Suprasorb P"]</div></td>
#       <td id="T_7c4d4_row3_col4" class="data row3 col4" ><div>["Suprasorb P Sensitive"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb Liquacel Pro"]</div></td>
#       <td id="T_7c4d4_row3_col5" class="data row3 col5" ><div>["Suprasorb Liquacel Pro", "Vliwasorb Pro"]</div><div style='border-top:1px dashed #adb5bd; margin:4px 0;'></div><div>["Suprasorb A + Ag", "Vliwasorb Pro"]</div></td>
#     </tr>
#     <tr>
#       <th id="T_7c4d4_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_7c4d4_row4_col0" class="data row4 col0" >wunde_08</td>
#       <td id="T_7c4d4_row4_c

# %%
# 5. Interaktive Einzelfall-Inspektion mit Wundbild (Dropdown)
category_loader.interactive_inspection('primärverband')
# Out:
# Dropdown(description='Wundbild:', layout=Layout(width='250px'), options=('wunde_01', 'wunde_02', 'wunde_03', '…
# Output()

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('.'))
import category_loader

# Plot mit 15 Balken anzeigen (Best-of-Both Konsens)
# Optional kannst du auch evaluation_mode='exp1' oder 'exp2' übergeben
category_loader.plot_primaerverband_bar_chart(evaluation_mode="best_of_both")

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('.'))
import category_loader

# Interaktiver Dropdown speziell für Primärverbände
category_loader.inspection_dropdown_primaerverband()
# Out:
# Dropdown(description='Wundbild:', layout=Layout(width='260px'), options=('wunde_01', 'wunde_02', 'wunde_03', '…
# Output()
